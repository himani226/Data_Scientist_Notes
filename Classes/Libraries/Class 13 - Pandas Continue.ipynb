# %% [markdown]
# ## Handle Missing Data
#
# Missing data can potentially give you a wrong result when you analyze data.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2,np.nan,4,5],
                  'B':[5,3,np.nan,6,7],
                  'C':[1,2,3,3,2],
                  'D':[np.nan,6,8,np.nan,6],
                  'E':[4,5,6,7,8],
                'F':['abc','fgh','dh','pq',np.nan]
                  })

# %%
df

# %% [markdown]
# #### Check for Null Values

# %%
df.isnull()

# %%
df.isnull().sum()

# %% [markdown]
# ### Remove Rows
#
# One way to deal with empty cells is to remove rows that contain empty cells.

# %%
df.dropna()

# %%
df.dropna(axis=1)

# %%
df.dropna(thresh=6)

# %% [markdown]
# “thresh=4” means that the rows that have at least 4 non-missing values will be kept. The other ones will be dropped.
#
# Our data frame has 5 columns so the rows that have 2 or more missing values will be dropped.

# %%
df

# %% [markdown]
# #### Drop based on a particular subset of columns

# %%
df.dropna(subset=['D'])

# %% [markdown]
# #### Fill with a constant value
#
# Choose a constant value to be used as a replacement for the missing values.
#
# One constant value to the ``fillna`` function, it will replace all the missing values in the data frame with that value.

# %%
df.fillna(value='FILL VALUE')

# %%
df.fillna(5)

# %%
df

# %% [markdown]
# #### Replace Only For Specified Columns

# %%
df["D"].fillna(5)

# %% [markdown]
# #### Fill with an aggregated value
#
# Another option is to use an aggregated value such as mean, median, or mode.

# %%
df["D"].fillna(df["D"].mean())

# %%
df["D"].fillna(df["D"].mode()[0])

# %%
x = df["D"].median()

df["D"].fillna(x)

# %% [markdown]
# #### Replace with the previous or next value
#
# Replace the missing values in a column with the previous or next value in that column.
#
# This method is working with time-series data. Suppose you have a data frame that contains the daily temperature measurement and the temperate in one day is missing. The optimal solution would be to use the temperature in the next or previous day.
#
# ``dataframe.bfill()`` is used to backward fill the missing values in the dataset.

# %%
#Backward Fill

df.fillna(method='bfill')

# %%
# Fill across the rows
df.bfill(axis = 1)

# %%
df

# %%
# Forward fill

df.fillna(method='ffill', axis=0)

# %%
df

# %%
df.ffill(axis=0, inplace = True)

# %%
df

# %% [markdown]
# ### Info on Unique Values

# %%
df['D'].unique()

# %%
df['D'].nunique()

# %%
df['C'].value_counts()

# %% [markdown]
# #### Applying Functions

# %%
def sq(x):
    return x*2

# %%
df

# %%
df['A'].apply(sq)

# %%
df['F'].apply(len)

# %%
df['A'].sum()

# %% [markdown]
# #### Permanently Removing a Column

# %%
del df['D']

# %%
df

# %% [markdown]
# ### Data Input and Output

# %% [markdown]
# #### Input

# %%
csv = pd.read_csv(r'..\Datasets\example')
csv

# %% [markdown]
# #### How to extract if file is present outside the folder

# %%
csv = pd.read_csv(r'C:\Users\Dell\example_outside')
csv

# %% [markdown]
# #### Output

# %%
csv.to_csv('sample',index=False)

# %% [markdown]
# ### Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %%
m = pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

m

# %% [markdown]
# #### Output

# %%
m.to_excel('Sample_file.xlsx')

# %% [markdown]
# ### Questions

# %% [markdown]
# Read csv file example from the folder and perform pandas operations on it.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Get Information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      float64
#  2   C       5 non-null      int64
#  3   D       3 non-null      float64
#  4   E       5 non-null      int64
#  5   F       4 non-null      object
# dtypes: float64(3), int64(2), object(1)
# memory usage: 368.0+ bytes

# %% [markdown]
# ### Handle Wrong Data

# %%
data = pd.read_csv(r'..\Datasets\data.csv')
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories    Fit
# 0         60  '2020/12/01'    110       130     409.1     no
# 1         60  '2020/12/02'    117       145     479.0    yes
# 2         60  '2020/12/03'    103       135     340.0     no
# 3         45  '2020/12/04'    109       175     282.4    yes
# 4         45  '2020/12/05'    117       148     406.0     no
# 5         60  '2020/12/06'    102       127     300.0     no
# 6         60  '2020/12/07'    110       136     374.0     no
# 7        450  '2020/12/08'    104       134     253.3    yes
# 8         30  '2020/12/09'    109       133     195.1    yes
# 9         60  '2020/12/10'     98       124     269.0     no
# 10        60  '2020/12/11'    103       147     329.3     no
# 11        60  '2020/12/12'    100       120     250.7    yes
# 12        60  '2020/12/12'    100       120     250.7  noyes
# 13        60  '2020/12/13'    106       128     345.3     no
# 14        60  '2020/12/14'    104       132     379.3     no
# 15        60  '2020/12/15'     98       123     275.0    yes
# 16        89  '2020/12/16'     98       120     215.2    yes
# 17        60  '2020/12/17'    100       120     300.0     no
# 18        45  '2020/12/18'     90       112       NaN     no
# 19        60  '2020/12/19'    103       123     323.0    yes
# 20        45  '2020/12/20'     97       125     243.0     no
# 21        60  '2020/12/21'    108       131     364.2     no
# 22        45           NaN    100       119     282.0    yes
# 23        60    23-12-2020    130       101     300.0     ni
# 24        45  '2020/12/24'    105       132     246.0     no
# 25        61  '2020/12/25'    102       126     334.5     no
# 26        60      20201226    100       120     250.0    yes
# 27        60  '2020/12/27'     92       118     241.0    yes
# 28        60  '2020/12/28'    103       132       NaN    yes
# 29        80  '2020/12/29'    100       132     280.0    yes
# 30        60  '2020/12/30'    102       129     380.3     no
# 31        60  '2020/12/31'     92       115     243.0    yes
# 32        60  '2020/12/31'     92       115     243.0    yes
# 33        60  '2020/12/31'     92       115     243.0    yes

# %%
data.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# Fit         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  34 non-null     int64
#  1   Date      33 non-null     object
#  2   Pulse     34 non-null     int64
#  3   Maxpulse  34 non-null     int64
#  4   Calories  32 non-null     float64
#  5   Fit       34 non-null     object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.7+ KB

# %%
data["Date"]
# Out:
# 0     '2020/12/01'
# 1     '2020/12/02'
# 2     '2020/12/03'
# 3     '2020/12/04'
# 4     '2020/12/05'
# 5     '2020/12/06'
# 6     '2020/12/07'
# 7     '2020/12/08'
# 8     '2020/12/09'
# 9     '2020/12/10'
# 10    '2020/12/11'
# 11    '2020/12/12'
# 12    '2020/12/12'
# 13    '2020/12/13'
# 14    '2020/12/14'
# 15    '2020/12/15'
# 16    '2020/12/16'
# 17    '2020/12/17'
# 18    '2020/12/18'
# 19    '2020/12/19'
# 20    '2020/12/20'
# 21    '2020/12/21'
# 22             NaN
# 23      23-12-2020
# 24    '2020/12/24'
# 25    '2020/12/25'
# 26        20201226
# 27    '2020/12/27'
# 28    '2020/12/28'
# 29    '2020/12/29'
# 30    '2020/12/30'
# 31    '2020/12/31'
# 32    '2020/12/31'
# 33    '2020/12/31'
# Name: Date, dtype: object

# %%
## Pandas has a to_datetime() method for Converting Date to right Format

data["Date"] = pd.to_datetime(data["Date"])
data["Date"]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14616\4284940110.py:3: UserWarning: Parsing '23-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data["Date"] = pd.to_datetime(data["Date"])
# 0    2020-12-01
# 1    2020-12-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
# 5    2020-12-06
# 6    2020-12-07
# 7    2020-12-08
# 8    2020-12-09
# 9    2020-12-10
# 10   2020-12-11
# 11   2020-12-12
# 12   2020-12-12
# 13   2020-12-13
# 14   2020-12-14
# 15   2020-12-15
# 16   2020-12-16
# 17   2020-12-17
# 18   2020-12-18
# 19   2020-12-19
# 20   2020-12-20
# 21   2020-12-21
# 22          NaT
# 23   2020-12-23
# 24   2020-12-24
# 25   2020-12-25
# 26   2020-12-26
# 27   2020-12-27
# 28   2020-12-28
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# 32   2020-12-31
# 33   2020-12-31
# Name: Date, dtype: datetime64[ns]

# %%
data['Date'].dropna()
# Out:
# 0    2020-12-01
# 1    2020-12-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
# 5    2020-12-06
# 6    2020-12-07
# 7    2020-12-08
# 8    2020-12-09
# 9    2020-12-10
# 10   2020-12-11
# 11   2020-12-12
# 12   2020-12-12
# 13   2020-12-13
# 14   2020-12-14
# 15   2020-12-15
# 16   2020-12-16
# 17   2020-12-17
# 18   2020-12-18
# 19   2020-12-19
# 20   2020-12-20
# 21   2020-12-21
# 23   2020-12-23
# 24   2020-12-24
# 25   2020-12-25
# 26   2020-12-26
# 27   2020-12-27
# 28   2020-12-28
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# 32   2020-12-31
# 33   2020-12-31
# Name: Date, dtype: datetime64[ns]

# %%
data.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories', 'Fit'], dtype='object')

# %%
data["Duration"]
# Out:
# 0      60
# 1      60
# 2      60
# 3      45
# 4      45
# 5      60
# 6      60
# 7     450
# 8      30
# 9      60
# 10     60
# 11     60
# 12     60
# 13     60
# 14     60
# 15     60
# 16     89
# 17     60
# 18     45
# 19     60
# 20     45
# 21     60
# 22     45
# 23     60
# 24     45
# 25     61
# 26     60
# 27     60
# 28     60
# 29     80
# 30     60
# 31     60
# 32     60
# 33     60
# Name: Duration, dtype: int64

# %%
# Replace Value

data.loc[7,"Duration"] = 45
data["Duration"]
# Out:
# 0     60
# 1     60
# 2     60
# 3     45
# 4     45
# 5     60
# 6     60
# 7     45
# 8     30
# 9     60
# 10    60
# 11    60
# 12    60
# 13    60
# 14    60
# 15    60
# 16    89
# 17    60
# 18    45
# 19    60
# 20    45
# 21    60
# 22    45
# 23    60
# 24    45
# 25    61
# 26    60
# 27    60
# 28    60
# 29    80
# 30    60
# 31    60
# 32    60
# 33    60
# Name: Duration, dtype: int64

# %% [markdown]
# To replace wrong data for larger data sets you can create some rules, e.g. set some boundaries for legal values, and replace any values that are outside of the boundaries

# %%
for x in data.index:
    if data.loc[x,"Duration"] > 60:
        data.loc[x,"Duration"] = 60
        
data["Duration"]
# Out:
# 0     60
# 1     60
# 2     60
# 3     45
# 4     45
# 5     60
# 6     60
# 7     45
# 8     30
# 9     60
# 10    60
# 11    60
# 12    60
# 13    60
# 14    60
# 15    60
# 16    60
# 17    60
# 18    45
# 19    60
# 20    45
# 21    60
# 22    45
# 23    60
# 24    45
# 25    60
# 26    60
# 27    60
# 28    60
# 29    60
# 30    60
# 31    60
# 32    60
# 33    60
# Name: Duration, dtype: int64

# %% [markdown]
# #### Removing Duplicates
#
# Duplicate rows are rows that have been registered more than one time
#
# To discover duplicates, we can use the duplicated() method
#
# The duplicated() method returns a Boolean values for each row
#
# To remove duplicates, use the drop_duplicates() method

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories    Fit
# 0         60 2020-12-01    110       130     409.1     no
# 1         60 2020-12-02    117       145     479.0    yes
# 2         60 2020-12-03    103       135     340.0     no
# 3         45 2020-12-04    109       175     282.4    yes
# 4         45 2020-12-05    117       148     406.0     no
# 5         60 2020-12-06    102       127     300.0     no
# 6         60 2020-12-07    110       136     374.0     no
# 7         45 2020-12-08    104       134     253.3    yes
# 8         30 2020-12-09    109       133     195.1    yes
# 9         60 2020-12-10     98       124     269.0     no
# 10        60 2020-12-11    103       147     329.3     no
# 11        60 2020-12-12    100       120     250.7    yes
# 12        60 2020-12-12    100       120     250.7  noyes
# 13        60 2020-12-13    106       128     345.3     no
# 14        60 2020-12-14    104       132     379.3     no
# 15        60 2020-12-15     98       123     275.0    yes
# 16        60 2020-12-16     98       120     215.2    yes
# 17        60 2020-12-17    100       120     300.0     no
# 18        45 2020-12-18     90       112       NaN     no
# 19        60 2020-12-19    103       123     323.0    yes
# 20        45 2020-12-20     97       125     243.0     no
# 21        60 2020-12-21    108       131     364.2     no
# 22        45        NaT    100       119     282.0    yes
# 23        60 2020-12-23    130       101     300.0     ni
# 24        45 2020-12-24    105       132     246.0     no
# 25        60 2020-12-25    102       126     334.5     no
# 26        60 2020-12-26    100       120     250.0    yes
# 27        60 2020-12-27     92       118     241.0    yes
# 28        60 2020-12-28    103       132       NaN    yes
# 29        60 2020-12-29    100       132     280.0    yes
# 30        60 2020-12-30    102       129     380.3     no
# 31        60 2020-12-31     92       115     243.0    yes
# 32        60 2020-12-31     92       115     243.0    yes
# 33        60 2020-12-31     92       115     243.0    yes

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories    Fit
# 0         60 2020-12-01    110       130     409.1     no
# 1         60 2020-12-02    117       145     479.0    yes
# 2         60 2020-12-03    103       135     340.0     no
# 3         45 2020-12-04    109       175     282.4    yes
# 4         45 2020-12-05    117       148     406.0     no
# 5         60 2020-12-06    102       127     300.0     no
# 6         60 2020-12-07    110       136     374.0     no
# 7         45 2020-12-08    104       134     253.3    yes
# 8         30 2020-12-09    109       133     195.1    yes
# 9         60 2020-12-10     98       124     269.0     no
# 10        60 2020-12-11    103       147     329.3     no
# 11        60 2020-12-12    100       120     250.7    yes
# 12        60 2020-12-12    100       120     250.7  noyes
# 13        60 2020-12-13    106       128     345.3     no
# 14        60 2020-12-14    104       132     379.3     no
# 15        60 2020-12-15     98       123     275.0    yes
# 16        60 2020-12-16     98       120     215.2    yes
# 17        60 2020-12-17    100       120     300.0     no
# 18        45 2020-12-18     90       112       NaN     no
# 19        60 2020-12-19    103       123     323.0    yes
# 20        45 2020-12-20     97       125     243.0     no
# 21        60 2020-12-21    108       131     364.2     no
# 22        45        NaT    100       119     282.0    yes
# 23        60 2020-12-23    130       101     300.0     ni
# 24        45 2020-12-24    105       132     246.0     no
# 25        60 2020-12-25    102       126     334.5     no
# 26        60 2020-12-26    100       120     250.0    yes
# 27        60 2020-12-27     92       118     241.0    yes
# 28        60 2020-12-28    103       132       NaN    yes
# 29        60 2020-12-29    100       132     280.0    yes
# 30        60 2020-12-30    102       129     380.3     no
# 31        60 2020-12-31     92       115     243.0    yes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  34 non-null     int64
#  1   Date      33 non-null     datetime64[ns]
#  2   Pulse     34 non-null     int64
#  3   Maxpulse  34 non-null     int64
#  4   Calories  32 non-null     float64
#  5   Fit       34 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# ### Pandas - Data Correlations
#
# Finding Relationships
#
# The corr() method calculates the relationship between each column in your data set
#
# The corr() method ignores "not numeric" columns
#
# The Result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns
#
# The number varies from -1 to 1
#
# 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well

# %%
data.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.107150 -0.281099  0.293904
# Pulse    -0.107150  1.000000  0.336311  0.549325
# Maxpulse -0.281099  0.336311  1.000000  0.396167
# Calories  0.293904  0.549325  0.396167  1.000000

# %% [markdown]
# **Perfect Correlation**
#
# We can see that "Duration" and "Duration" got the number 1.000000, which makes sense, each column always has a perfect relationship with itself
#
# **Good Correlation**
#
# "Duration" and "Calories" got a 0.293904 correlation, which is a very good correlation, and we can predict that the longer you work out, the more calories you burn, and the other way around: if you burned a lot of calories, you probably had a long work out
#
# **Bad Correlation**
#
# "Duration" and "Maxpulse" got a 0.009403 correlation, which is a very bad correlation, meaning that we can not predict the max pulse by just looking at the duration of the work out, and vice versa

# %% [markdown]
# ### isnull() Conditional Selector
#
# To select NaN entries you can use pd.isnull()

# %%
data[pd.isnull(data['Calories'])]
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories  Fit
# 18        45 2020-12-18     90       112       NaN   no
# 28        60 2020-12-28    103       132       NaN  yes

# %%
data['Fit']
# Out:
# 0        no
# 1       yes
# 2        no
# 3       yes
# 4        no
# 5        no
# 6        no
# 7       yes
# 8       yes
# 9        no
# 10       no
# 11      yes
# 12    noyes
# 13       no
# 14       no
# 15      yes
# 16      yes
# 17       no
# 18       no
# 19      yes
# 20       no
# 21       no
# 22      yes
# 23       ni
# 24       no
# 25       no
# 26      yes
# 27      yes
# 28      yes
# 29      yes
# 30       no
# 31      yes
# 32      yes
# 33      yes
# Name: Fit, dtype: object

# %%
data['Fit'].replace(['noyes'], 'no')
# Out:
# 0      no
# 1     yes
# 2      no
# 3     yes
# 4      no
# 5      no
# 6      no
# 7     yes
# 8     yes
# 9      no
# 10     no
# 11    yes
# 12     no
# 13     no
# 14     no
# 15    yes
# 16    yes
# 17     no
# 18     no
# 19    yes
# 20     no
# 21     no
# 22    yes
# 23     ni
# 24     no
# 25     no
# 26    yes
# 27    yes
# 28    yes
# 29    yes
# 30     no
# 31    yes
# 32    yes
# 33    yes
# Name: Fit, dtype: object

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories    Fit
# 0         60 2020-12-01    110       130     409.1     no
# 1         60 2020-12-02    117       145     479.0    yes
# 2         60 2020-12-03    103       135     340.0     no
# 3         45 2020-12-04    109       175     282.4    yes
# 4         45 2020-12-05    117       148     406.0     no
# 5         60 2020-12-06    102       127     300.0     no
# 6         60 2020-12-07    110       136     374.0     no
# 7         45 2020-12-08    104       134     253.3    yes
# 8         30 2020-12-09    109       133     195.1    yes
# 9         60 2020-12-10     98       124     269.0     no
# 10        60 2020-12-11    103       147     329.3     no
# 11        60 2020-12-12    100       120     250.7    yes
# 12        60 2020-12-12    100       120     250.7  noyes
# 13        60 2020-12-13    106       128     345.3     no
# 14        60 2020-12-14    104       132     379.3     no
# 15        60 2020-12-15     98       123     275.0    yes
# 16        60 2020-12-16     98       120     215.2    yes
# 17        60 2020-12-17    100       120     300.0     no
# 18        45 2020-12-18     90       112       NaN     no
# 19        60 2020-12-19    103       123     323.0    yes
# 20        45 2020-12-20     97       125     243.0     no
# 21        60 2020-12-21    108       131     364.2     no
# 22        45        NaT    100       119     282.0    yes
# 23        60 2020-12-23    130       101     300.0     ni
# 24        45 2020-12-24    105       132     246.0     no
# 25        60 2020-12-25    102       126     334.5     no
# 26        60 2020-12-26    100       120     250.0    yes
# 27        60 2020-12-27     92       118     241.0    yes
# 28        60 2020-12-28    103       132       NaN    yes
# 29        60 2020-12-29    100       132     280.0    yes
# 30        60 2020-12-30    102       129     380.3     no
# 31        60 2020-12-31     92       115     243.0    yes
# 32        60 2020-12-31     92       115     243.0    yes
# 33        60 2020-12-31     92       115     243.0    yes

# %%
data['Fit'].replace(['noyes'], 'no', inplace=True)

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories  Fit
# 0         60 2020-12-01    110       130     409.1   no
# 1         60 2020-12-02    117       145     479.0  yes
# 2         60 2020-12-03    103       135     340.0   no
# 3         45 2020-12-04    109       175     282.4  yes
# 4         45 2020-12-05    117       148     406.0   no
# 5         60 2020-12-06    102       127     300.0   no
# 6         60 2020-12-07    110       136     374.0   no
# 7         45 2020-12-08    104       134     253.3  yes
# 8         30 2020-12-09    109       133     195.1  yes
# 9         60 2020-12-10     98       124     269.0   no
# 10        60 2020-12-11    103       147     329.3   no
# 11        60 2020-12-12    100       120     250.7  yes
# 12        60 2020-12-12    100       120     250.7   no
# 13        60 2020-12-13    106       128     345.3   no
# 14        60 2020-12-14    104       132     379.3   no
# 15        60 2020-12-15     98       123     275.0  yes
# 16        60 2020-12-16     98       120     215.2  yes
# 17        60 2020-12-17    100       120     300.0   no
# 18        45 2020-12-18     90       112       NaN   no
# 19        60 2020-12-19    103       123     323.0  yes
# 20        45 2020-12-20     97       125     243.0   no
# 21        60 2020-12-21    108       131     364.2   no
# 22        45        NaT    100       119     282.0  yes
# 23        60 2020-12-23    130       101     300.0   ni
# 24        45 2020-12-24    105       132     246.0   no
# 25        60 2020-12-25    102       126     334.5   no
# 26        60 2020-12-26    100       120     250.0  yes
# 27        60 2020-12-27     92       118     241.0  yes
# 28        60 2020-12-28    103       132       NaN  yes
# 29        60 2020-12-29    100       132     280.0  yes
# 30        60 2020-12-30    102       129     380.3   no
# 31        60 2020-12-31     92       115     243.0  yes
# 32        60 2020-12-31     92       115     243.0  yes
# 33        60 2020-12-31     92       115     243.0  yes

# %%
data["Fit_encoded"]=data['Fit'].map(dict(yes=1, no=0))

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories  Fit  Fit_encoded
# 0         60 2020-12-01    110       130     409.1   no          0.0
# 1         60 2020-12-02    117       145     479.0  yes          1.0
# 2         60 2020-12-03    103       135     340.0   no          0.0
# 3         45 2020-12-04    109       175     282.4  yes          1.0
# 4         45 2020-12-05    117       148     406.0   no          0.0
# 5         60 2020-12-06    102       127     300.0   no          0.0
# 6         60 2020-12-07    110       136     374.0   no          0.0
# 7         45 2020-12-08    104       134     253.3  yes          1.0
# 8         30 2020-12-09    109       133     195.1  yes          1.0
# 9         60 2020-12-10     98       124     269.0   no          0.0
# 10        60 2020-12-11    103       147     329.3   no          0.0
# 11        60 2020-12-12    100       120     250.7  yes          1.0
# 12        60 2020-12-12    100       120     250.7   no          0.0
# 13        60 2020-12-13    106       128     345.3   no          0.0
# 14        60 2020-12-14    104       132     379.3   no          0.0
# 15        60 2020-12-15     98       123     275.0  yes          1.0
# 16        60 2020-12-16     98       120     215.2  yes          1.0
# 17        60 2020-12-17    100       120     300.0   no          0.0
# 18        45 2020-12-18     90       112       NaN   no          0.0
# 19        60 2020-12-19    103       123     323.0  yes          1.0
# 20        45 2020-12-20     97       125     243.0   no          0.0
# 21        60 2020-12-21    108       131     364.2   no          0.0
# 22        45        NaT    100       119     282.0  yes          1.0
# 23        60 2020-12-23    130       101     300.0   ni          NaN
# 24        45 2020-12-24    105       132     246.0   no          0.0
# 25        60 2020-12-25    102       126     334.5   no          0.0
# 26        60 2020-12-26    100       120     250.0  yes          1.0
# 27        60 2020-12-27     92       118     241.0  yes          1.0
# 28        60 2020-12-28    103       132       NaN  yes          1.0
# 29        60 2020-12-29    100       132     280.0  yes          1.0
# 30        60 2020-12-30    102       129     380.3   no          0.0
# 31        60 2020-12-31     92       115     243.0  yes          1.0
# 32        60 2020-12-31     92       115     243.0  yes          1.0
# 33        60 2020-12-31     92       115     243.0  yes          1.0
